# %% [markdown]
# # CS-GY 6953 Deep Learning Mini-Project

# %% [markdown]
# ## A Shallow ResNet
# Task: Building a ResNet model on CIFAR-10 with a constraint of 5 million parameters maximum.

# %% [markdown]
# ## 1. Starting Simple: Load the CIFAR-10 dataset and build the first shallow ResNet network

# %% [markdown]
# Create the data loaders.

# %%
# !pip install torchvision
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchvision in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: torch==1.13.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.23.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (65.5.0)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.37.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: torchsummary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.5.1)

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
batch_size = 128

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])
# There are more functions for augmentation.
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data',train=False, download=True, transform=transform_test)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Construct the ResNet.

# %%
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchsummary import summary

import os

# %%
class BasicBlock(nn.Module): # A residual block with 2 convolutional layers and a skip connection.
    expansion = 1
    
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes,      # Number of channels in the input image
                               planes,         # Number of output channels
                               kernel_size=3,  # Size of the convolution filter
                               stride=stride,  # Stride of the convolution
                               padding=1,      # Padding added to all four sides of the input, int or {'valid', 'same'}, etc.
                               # padding_mode={'zeros', 'reflect', 'replicate', 'circular'}
                               bias=False)     # If true, adds a learnable bias ot the output.
        self.bn1 = nn.BatchNorm2d(planes)      # Other parameters include eps, momentum, affine, etc.
                                               # affine=True: affine parameters being learnable.
        self.conv2 = nn.Conv2d(planes, 
                               planes, 
                               kernel_size=3,
                               stride=1,
                               padding=1,
                               bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()        # A sequentil wrapper of layers.
        # If the dimentions of skip connection input and output don't match, do the following.
        # As an alternative solution, zero-padding is also proposed in the paper.
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(nn.Conv2d(in_planes, 
                                                    self.expansion*planes, 
                                                    kernel_size=1, 
                                                    stride=stride, 
                                                    bias=False),
                                          nn.BatchNorm2d(self.expansion*planes))
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64
        
        self.conv1 = nn.Conv2d(3, 64, 
                               kernel_size=3, 
                               stride=1, 
                               padding=1, 
                               bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        # self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        # self.linear = nn.Linear(512*block.expansion, num_classes)
        self.linear = nn.Linear(256*block.expansion, num_classes)
        
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes*block.expansion
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        # out = self.layer4(out)
        # out = F.avg_pool2d(out, 4)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet(BasicBlock, [2,2,2,2])

# %%
summary(model, (3, 32, 32), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Linear-37                   [-1, 10]           2,570
# ================================================================
# Total params: 2,777,674
# Trainable params: 2,777,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.50
# Params size (MB): 10.60
# Estimated Total Size (MB): 21.11
# ----------------------------------------------------------------

# %% [markdown]
# Note: No non-linearity in the fully connected part.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"The device is {device}")
model = model.to(device)
if device == 'cuda':
    model = torch.nn.DataParallel(model)
    cudnn.benchmark = True
# Out:
# The device is cuda

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=0.1, 
                      momentum=0.9, 
                      weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.1, patience=15)

# %%
model_chk_name =  'shallow_ckpt_with_LRplateau'

# %%
def train(epoch):
    print('\nEpoch: %d'%epoch)
    model.train()
    train_loss = 0
    correct, total = 0, 0
    for (inputs, targets) in trainloader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
    acc = correct/total*100
    train_loss /= total
    print(f"Train | Loss: {round(train_loss, 4)} | Acc: {round(acc, 2)}")
    train_losses.append(train_loss)
    train_accs.append(acc)

def test(epoch):
    global train_losses, test_losses, train_accs, test_accs, lrs, best_acc
    model.eval()
    test_loss = 0
    correct, total = 0, 0
    with torch.no_grad():
        for (inputs, targets) in testloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    acc = correct/total*100
    test_loss /= total
    print(f"Test  | Loss: {round(test_loss, 4)} | Acc: {round(acc, 2)}")
    test_losses.append(test_loss)
    test_accs.append(acc)
    
    state = {'model': model.state_dict(),
             'train_loss': train_losses,
             'test_loss': test_losses,
             'train_acc': train_accs,
             'test_acc': test_accs,
             'lr':lrs,
             'epoch': epoch}
    torch.save(state, './checkpoint/'+model_chk_name+'.pth')
    if acc > best_acc:
        torch.save(state, './checkpoint/'+model_chk_name+'_best.pth')
        best_acc = acc

if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')
state = {'model': model.state_dict(),
         'train_loss': [],
         'test_loss': [],
         'train_acc': [],
         'test_acc': [],
         'lr':[],
         'epoch': -1}
torch.save(state, './checkpoint/'+model_chk_name+'.pth')
torch.save(state, './checkpoint/'+model_chk_name+'_best.pth')

# %%
checkpoint = torch.load('./checkpoint/'+model_chk_name+'.pth')
model.load_state_dict(checkpoint['model'])
train_losses = checkpoint['train_loss']
test_losses = checkpoint['test_loss']
train_accs = checkpoint['train_acc']
test_accs = checkpoint['test_acc']
lrs = checkpoint['lr']
best_acc = 0.0 if not test_accs else max(test_accs)
start_epoch = checkpoint['epoch']
print("\n Starting epoch : ",start_epoch)
print("\n Starting best_acc : ",best_acc)
# Out:
#  Starting epoch :  -1
#
#  Starting best_acc :  0.0

# %%
for epoch in range(start_epoch +1, start_epoch + 201):
    train(epoch)
    test(epoch)
    lrs.append(optimizer.param_groups[0]['lr'])
    scheduler.step(test_accs[-1])
# Out:
# Epoch: 0
# Train | Loss: 0.0135 | Acc: 35.85
# Test  | Loss: 0.0116 | Acc: 45.59
#
# Epoch: 1
# Train | Loss: 0.0097 | Acc: 54.71
# Test  | Loss: 0.0103 | Acc: 55.82
#
# Epoch: 2
# Train | Loss: 0.0077 | Acc: 64.98
# Test  | Loss: 0.0077 | Acc: 66.76
#
# Epoch: 3
# Train | Loss: 0.0064 | Acc: 71.46
# Test  | Loss: 0.0077 | Acc: 67.73
#
# Epoch: 4
# Train | Loss: 0.0054 | Acc: 75.88
# Test  | Loss: 0.006 | Acc: 75.18
#
# Epoch: 5
# Train | Loss: 0.0048 | Acc: 79.16
# Test  | Loss: 0.0048 | Acc: 79.33
#
# Epoch: 6
# Train | Loss: 0.0043 | Acc: 80.99
# Test  | Loss: 0.0055 | Acc: 77.01
#
# Epoch: 7
# Train | Loss: 0.004 | Acc: 82.35
# Test  | Loss: 0.0052 | Acc: 78.74
#
# Epoch: 8
# Train | Loss: 0.0038 | Acc: 83.45
# Test  | Loss: 0.0048 | Acc: 79.81
#
# Epoch: 9
# Train | Loss: 0.0036 | Acc: 84.18
# Test  | Loss: 0.0051 | Acc: 78.71
#
# Epoch: 10
# Train | Loss: 0.0034 | Acc: 84.97
# Test  | Loss: 0.0042 | Acc: 82.36
#
# Epoch: 11
# Train | Loss: 0.0033 | Acc: 85.45
# Test  | Loss: 0.005 | Acc: 79.41
#
# Epoch: 12
# Train | Loss: 0.0032 | Acc: 86.05
# Test  | Loss: 0.0041 | Acc: 82.97
#
# Epoch: 13
# Train | Loss: 0.0031 | Acc: 86.16
# Test  | Loss: 0.007 | Acc: 72.48
#
# Epoch: 14
# Train | Loss: 0.0031 | Acc: 86.27
# Test  | Loss: 0.0042 | Acc: 82.69
#
# Epoch: 15
# Train | Loss: 0.003 | Acc: 86.82
# Test  | Loss: 0.0038 | Acc: 83.4
#
# Epoch: 16
# Train | Loss: 0.0029 | Acc: 87.06
# Test  | Loss: 0.0056 | Acc: 77.97
#
# Epoch: 17
# Train | Loss: 0.0029 | Acc: 87.28
# Test  | Loss: 0.0042 | Acc: 82.4
#
# Epoch: 18
# Train | Loss: 0.0028 | Acc: 87.75
# Test  | Loss: 0.0054 | Acc: 78.66
#
# Epoch: 19
# Train | Loss: 0.0028 | Acc: 87.52
# Test  | Loss: 0.0041 | Acc: 83.29
#
# Epoch: 20
# Train | Loss: 0.0028 | Acc: 87.96
# Test  | Loss: 0.0039 | Acc: 83.94
#
# Epoch: 21
# Train | Loss: 0.0028 | Acc: 87.9
# Test  | Loss: 0.0035 | Acc: 84.99
#
# Epoch: 22
# Train | Loss: 0.0027 | Acc: 88.14
# Test  | Loss: 0.0051 | Acc: 79.81
#
# Epoch: 23
# Train | Loss: 0.0027 | Acc: 88.04
# Test  | Loss: 0.0038 | Acc: 83.87
#
# Epoch: 24
# Train | Loss: 0.0027 | Acc: 88.26
# Test  | Loss: 0.0039 | Acc: 83.52
#
# Epoch: 25
# Train | Loss: 0.0026 | Acc: 88.68
# Test  | Loss: 0.0042 | Acc: 82.59
#
# Epoch: 26
# Train | Loss: 0.0027 | Acc: 88.41
# Test  | Loss: 0.0042 | Acc: 82.72
#
# Epoch: 27
# Train | Loss: 0.0026 | Acc: 88.46
# Test  | Loss: 0.0037 | Acc: 84.75
#
# Epoch: 28
# Train | Loss: 0.0026 | Acc: 88.45
# Test  | Loss: 0.0037 | Acc: 84.34
#
# Epoch: 29
# Train | Loss: 0.0026 | Acc: 88.64
# Test  | Loss: 0.0039 | Acc: 84.25
#
# Epoch: 30
# Train | Loss: 0.0026 | Acc: 88.75
# Test  | Loss: 0.0046 | Acc: 81.38
#
# Epoch: 31
# Train | Loss: 0.0025 | Acc: 89.16
# Test  | Loss: 0.0047 | Acc: 81.54
#
# Epoch: 32
# Train | Loss: 0.0025 | Acc: 88.95
# Test  | Loss: 0.0063 | Acc: 76.15
#
# Epoch: 33
# Train | Loss: 0.0026 | Acc: 88.76
# Test  | Loss: 0.0036 | Acc: 84.36
#
# Epoch: 34
# Train | Loss: 0.0025 | Acc: 88.84
# Test  | Loss: 0.0041 | Acc: 83.83
#
# Epoch: 35
# Train | Loss: 0.0025 | Acc: 88.96
# Test  | Loss: 0.0044 | Acc: 82.36
#
# Epoch: 36
# Train | Loss: 0.0025 | Acc: 88.8
# Test  | Loss: 0.0043 | Acc: 82.41
#
# Epoch: 37
# Train | Loss: 0.0025 | Acc: 88.93
# Test  | Loss: 0.004 | Acc: 83.34
#
# Epoch: 38
# Train | Loss: 0.0014 | Acc: 94.12
# Test  | Loss: 0.0017 | Acc: 92.46
#
# Epoch: 39
# Train | Loss: 0.001 | Acc: 95.85
# Test  | Loss: 0.0017 | Acc: 92.84
#
# Epoch: 40
# Train | Loss: 0.0009 | Acc: 96.24
# Test  | Loss: 0.0017 | Acc: 92.84
#
# Epoch: 41
# Train | Loss: 0.0007 | Acc: 96.97
# Test  | Loss: 0.0016 | Acc: 93.22
#
# Epoch: 42
# Train | Loss: 0.0007 | Acc: 97.27
# Test  | Loss: 0.0016 | Acc: 93.24
#
# Epoch: 43
# Train | Loss: 0.0006 | Acc: 97.55
# Test  | Loss: 0.0017 | Acc: 93.29
#
# Epoch: 44
# Train | Loss: 0.0006 | Acc: 97.78
# Test  | Loss: 0.0016 | Acc: 93.42
#
# Epoch: 45
# Train | Loss: 0.0005 | Acc: 98.02
# Test  | Loss: 0.0016 | Acc: 93.65
#
# Epoch: 46
# Train | Loss: 0.0005 | Acc: 98.22
# Test  | Loss: 0.0017 | Acc: 93.33
#
# Epoch: 47
# Train | Loss: 0.0004 | Acc: 98.39
# Test  | Loss: 0.0016 | Acc: 93.56
#
# Epoch: 48
# Train | Loss: 0.0004 | Acc: 98.59
# Test  | Loss: 0.0016 | Acc: 93.67
#
# Epoch: 49
# Train | Loss: 0.0004 | Acc: 98.69
# Test  | Loss: 0.0017 | Acc: 93.41
#
# Epoch: 50
# Train | Loss: 0.0003 | Acc: 98.92
# Test  | Loss: 0.0017 | Acc: 93.36
#
# Epoch: 51
# Train | Loss: 0.0003 | Acc: 98.92
# Test  | Loss: 0.0017 | Acc: 93.5
#
# Epoch: 52
# Train | Loss: 0.0003 | Acc: 99.01
# Test  | Loss: 0.0017 | Acc: 93.42
#
# Epoch: 53
# Train | Loss: 0.0003 | Acc: 99.08
# Test  | Loss: 0.0017 | Acc: 93.63
#
# Epoch: 54
# Train | Loss: 0.0003 | Acc: 99.1
# Test  | Loss: 0.0018 | Acc: 93.44
#
# Epoch: 55
# Train | Loss: 0.0003 | Acc: 99.15
# Test  | Loss: 0.0018 | Acc: 93.52
#
# Epoch: 56
# Train | Loss: 0.0002 | Acc: 99.23
# Test  | Loss: 0.0018 | Acc: 93.7
#
# Epoch: 57
# Train | Loss: 0.0002 | Acc: 99.19
# Test  | Loss: 0.0019 | Acc: 93.37
#
# Epoch: 58
# Train | Loss: 0.0002 | Acc: 99.33
# Test  | Loss: 0.0019 | Acc: 93.34
#
# Epoch: 59
# Train | Loss: 0.0002 | Acc: 99.32
# Test  | Loss: 0.0017 | Acc: 93.44
#
# Epoch: 60
# Train | Loss: 0.0002 | Acc: 99.36
# Test  | Loss: 0.0019 | Acc: 93.34
#
# Epoch: 61
# Train | Loss: 0.0003 | Acc: 99.1
# Test  | Loss: 0.0019 | Acc: 93.21
#
# Epoch: 62
# Train | Loss: 0.0002 | Acc: 99.29
# Test  | Loss: 0.0019 | Acc: 93.08
#
# Epoch: 63
# Train | Loss: 0.0002 | Acc: 99.31
# Test  | Loss: 0.002 | Acc: 92.81
#
# Epoch: 64
# Train | Loss: 0.0002 | Acc: 99.21
# Test  | Loss: 0.002 | Acc: 92.92
#
# Epoch: 65
# Train | Loss: 0.0002 | Acc: 99.36
# Test  | Loss: 0.0019 | Acc: 92.93
#
# Epoch: 66
# Train | Loss: 0.0002 | Acc: 99.39
# Test  | Loss: 0.0018 | Acc: 93.46
#
# Epoch: 67
# Train | Loss: 0.0002 | Acc: 99.27
# Test  | Loss: 0.002 | Acc: 92.68
#
# Epoch: 68
# Train | Loss: 0.0003 | Acc: 99.1
# Test  | Loss: 0.002 | Acc: 92.73
#
# Epoch: 69
# Train | Loss: 0.0003 | Acc: 99.11
# Test  | Loss: 0.0019 | Acc: 93.09
#
# Epoch: 70
# Train | Loss: 0.0003 | Acc: 99.0
# Test  | Loss: 0.0021 | Acc: 92.8
#
# Epoch: 71
# Train | Loss: 0.0003 | Acc: 99.0
# Test  | Loss: 0.002 | Acc: 92.97
#
# Epoch: 72
# Train | Loss: 0.0003 | Acc: 99.01
# Test  | Loss: 0.0019 | Acc: 92.89
#
# Epoch: 73
# Train | Loss: 0.0002 | Acc: 99.57
# Test  | Loss: 0.0016 | Acc: 93.96
#
# Epoch: 74
# Train | Loss: 0.0001 | Acc: 99.78
# Test  | Loss: 0.0016 | Acc: 94.13
#
# Epoch: 75
# Train | Loss: 0.0001 | Acc: 99.84
# Test  | Loss: 0.0016 | Acc: 94.26
#
# Epoch: 76
# Train | Loss: 0.0001 | Acc: 99.88
# Test  | Loss: 0.0016 | Acc: 94.26
#
# Epoch: 77
# Train | Loss: 0.0001 | Acc: 99.9
# Test  | Loss: 0.0015 | Acc: 94.32
#
# Epoch: 78
# Train | Loss: 0.0001 | Acc: 99.9
# Test  | Loss: 0.0016 | Acc: 94.55
#
# Epoch: 79
# Train | Loss: 0.0001 | Acc: 99.94
# Test  | Loss: 0.0016 | Acc: 94.41
#
# Epoch: 80
# Train | Loss: 0.0001 | Acc: 99.92
# Test  | Loss: 0.0015 | Acc: 94.33
#
# Epoch: 81
# Train | Loss: 0.0001 | Acc: 99.93
# Test  | Loss: 0.0015 | Acc: 94.39
#
# Epoch: 82
# Train | Loss: 0.0001 | Acc: 99.95
# Test  | Loss: 0.0016 | Acc: 94.38
#
# Epoch: 83
# Train | Loss: 0.0001 | Acc: 99.93
# Test  | Loss: 0.0015 | Acc: 94.46
#
# Epoch: 84
# Train | Loss: 0.0001 | Acc: 99.94
# Test  | Loss: 0.0016 | Acc: 94.43
#
# Epoch: 85
# Train | Loss: 0.0001 | Acc: 99.95
# Test  | Loss: 0.0016 | Acc: 94.34
#
# Epoch: 86
# Train | Loss: 0.0001 | Acc: 99.95
# Test  | Loss: 0.0015 | Acc: 94.29
#
# Epoch: 87
# Train | Loss: 0.0001 | Acc: 99.96
# Test  | Loss: 0.0015 | Acc: 94.38
#
# Epoch: 88
# Train | Loss: 0.0001 | Acc: 99.96
# Test  | Loss: 0.0015 | Acc: 94.46
#
# Epoch: 89
# Train | Loss: 0.0001 | Acc: 99.96
# Test  | Loss: 0.0015 | Acc: 94.46
#
# Epoch: 90
# Train | Loss: 0.0 | Acc: 99.97
# Test  | Loss: 0.0016 | Acc: 94.32
#
# Epoch: 91
# Train | Loss: 0.0 | Acc: 99.97
# Test  | Loss: 0.0015 | Acc: 94.52
#
# Epoch: 92
# Train | Loss: 0.0 | Acc: 99.98
# Test  | Loss: 0.0015 | Acc: 94.43
#
# Epoch: 93
# Train | Loss: 0.0 | Acc: 99.95
# Test  | Loss: 0.0015 | Acc: 94.44
#
# Epoch: 94
# Train | Loss: 0.0 | Acc: 99.98
# Test  | Loss: 0.0015 | Acc: 94.36
#
# Epoch: 95
# Train | Loss: 0.0 | Acc: 99.98
# Test  | Loss: 0.0016 | Acc: 94.45
#
# Epoch: 96
# Train | Loss: 0.0 | Acc: 99.96
# Test  | Loss: 0.0015 | Acc: 94.38
#
# Epoch: 97
# Train | Loss: 0.0 | Acc: 99.97
# Test  | Loss: 0.0016 | Acc: 94.42
#
# Epoch: 98
# Train | Loss: 0.0 | Acc: 99.97
# Test  | Loss: 0.0016 | Acc: 94.39
#
# Epoch: 99
# Train | Loss: 0.0 | Acc: 99.97
# Test  | Loss: 0.0016 | Acc: 94.45
#
# Epoch: 100
# Train | Loss: 0.0 | Acc: 99.98
# Test  | Loss: 0.0016 | Acc: 94.42
#
# Epoch: 101
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_261/3191194035.py in <cell line: 1>()
#       1 for epoch in range(start_epoch +1, start_epoch + 201):
# ----> 2     train(epoch)
#       3     test(epoch)
#       4     lrs.append(optimizer.param_groups[0]['lr'])
#       5     scheduler.step(test_accs[-1])
#
# /tmp/ipykernel_261/973245359.py in train(epoch)
#      12         optimizer.step()
#      13
# ---> 14         train_loss += loss.item()
#      15         _, predicted = outputs.max(1)
#      16         total += targets.size(0)
#
# KeyboardInterrupt:

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize = (10,3))
plt.subplot(1, 2, 1)
plt.plot(range(len(train_losses)), train_losses, label = 'Train loss')
plt.plot(range(len(test_losses)), test_losses, label = 'Val loss')
plt.title('Loss curve')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(range(len(train_losses)), train_accs, label = 'Train acc')
plt.plot(range(len(test_losses)), test_accs, label = 'Val acc')
plt.title('Accuracy curve')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: numpy>=1.19 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# The loss should have divided by the number of samples...

# %%
best_acc
# Out:
# 94.55
